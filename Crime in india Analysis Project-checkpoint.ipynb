# %% [markdown]
# About the Dataset
#
# This dataset contains complete information about various aspects of crimes happened in India from 2001. There are many factors that can be analysed from this dataset. Over all, I hope this dataset helps us to understand better about India.
#
# Victims of CH not Amounting to Murder (Age & Sex-wise)
#
# Male Victims
#
# Female Victims
#
# Total

# %%
# Importing libraries

import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# The Dataset

# %%
df = pd.read_csv('33_CH_not_murder_victim_age_sex.csv')

# %% [markdown]
#  (EDA) Exploratory Data Analysis And Data Cleaning

# %%
df
# Out:
#              Area_Name  Year   Sub_Group_Name  Victims_Above_50_Yrs  \
# 0       Andhra Pradesh  2001  1. Male Victims                  17.0
# 1    Arunachal Pradesh  2001  1. Male Victims                   1.0
# 2                Assam  2001  1. Male Victims                   2.0
# 3                Bihar  2001  1. Male Victims                  20.0
# 4           Chandigarh  2001  1. Male Victims                   0.0
# ..                 ...   ...              ...                   ...
# 931         Tamil Nadu  2010         3. Total                   3.0
# 932            Tripura  2010         3. Total                   0.0
# 933      Uttar Pradesh  2010         3. Total                 137.0
# 934        Uttarakhand  2010         3. Total                   2.0
# 935        West Bengal  2010         3. Total                  56.0
#
#      Victims_Total  Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  \
# 0            144.0                     3.0                  1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 936 entries, 0 to 935
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Area_Name               936 non-null    object
#  1   Year                    936 non-null    int64
#  2   Sub_Group_Name          936 non-null    object
#  3   Victims_Above_50_Yrs    831 non-null    float64
#  4   Victims_Total           934 non-null    float64
#  5   Victims_Upto_10_15_Yrs  765 non-null    float64
#  6   Victims_Upto_10_Yrs     780 non-null    float64
#  7   Victims_Upto_15_18_Yrs  776 non-null    float64
#  8   Victims_Upto_18_30_Yrs  883 non-null    float64
#  9   Victims_Upto_30_50_Yrs  893 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 73.2+ KB

# %%
df.head()
# Out:
#            Area_Name  Year   Sub_Group_Name  Victims_Above_50_Yrs  \
# 0     Andhra Pradesh  2001  1. Male Victims                  17.0
# 1  Arunachal Pradesh  2001  1. Male Victims                   1.0
# 2              Assam  2001  1. Male Victims                   2.0
# 3              Bihar  2001  1. Male Victims                  20.0
# 4         Chandigarh  2001  1. Male Victims                   0.0
#
#    Victims_Total  Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  \
# 0          144.0                     3.0                  1.0
# 1            6.0                     0.0                  0.0
# 2           38.0                     0.0                  0.0
# 3          232.0                     3.0                  0.0
# 4            6.0                     NaN                  0.0
#
#    Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs
# 0                     5.0                    54.0                    64.0
# ...

# %%
df.tail()
# Out:
#          Area_Name  Year Sub_Group_Name  Victims_Above_50_Yrs  Victims_Total  \
# 931     Tamil Nadu  2010       3. Total                   3.0           33.0
# 932        Tripura  2010       3. Total                   0.0            8.0
# 933  Uttar Pradesh  2010       3. Total                 137.0         1411.0
# 934    Uttarakhand  2010       3. Total                   2.0           60.0
# 935    West Bengal  2010       3. Total                  56.0          630.0
#
#      Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  \
# 931                     0.0                  2.0                     2.0
# 932                     0.0                  3.0                     1.0
# 933                    26.0                  9.0                    40.0
# 934                     NaN                  NaN                     NaN
# 935                    11.0                  1.0                    25.0
#
#      Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs
# ...

# %%
df.shape
# Out:
# (936, 10)

# %%
df.describe()
# Out:
#               Year  Victims_Above_50_Yrs  Victims_Total  \
# count   936.000000            831.000000     934.000000
# mean   2005.567308              7.716005      86.871520
# std       2.869303             20.621809     213.249414
# min    2001.000000              0.000000       0.000000
# 25%    2003.000000              0.000000       4.000000
# 50%    2006.000000              2.000000      21.000000
# 75%    2008.000000              6.000000      79.000000
# max    2010.000000            163.000000    1622.000000
#
#        Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  \
# count              765.000000           780.000000              776.000000
# mean                 2.083660             1.876923                4.216495
# std                  6.238565             4.537136               12.173776
# min                  0.000000             0.000000                0.000000
# 25%                  0.000000             0.000000                0.000000
# ...

# %%
df.describe(include='all')
# Out:
#              Area_Name         Year Sub_Group_Name  Victims_Above_50_Yrs  \
# count              936   936.000000            936            831.000000
# unique              35          NaN              3                   NaN
# top     Andhra Pradesh          NaN       3. Total                   NaN
# freq                30          NaN            325                   NaN
# mean               NaN  2005.567308            NaN              7.716005
# std                NaN     2.869303            NaN             20.621809
# min                NaN  2001.000000            NaN              0.000000
# 25%                NaN  2003.000000            NaN              0.000000
# 50%                NaN  2006.000000            NaN              2.000000
# 75%                NaN  2008.000000            NaN              6.000000
# max                NaN  2010.000000            NaN            163.000000
#
#         Victims_Total  Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  \
# ...

# %%
# checking uniqce values which is in objects columns.
df.describe(include='object')
# Out:
#              Area_Name Sub_Group_Name
# count              936            936
# unique              35              3
# top     Andhra Pradesh       3. Total
# freq                30            325

# %%
df.isnull().sum()
# Out:
# Area_Name                   0
# Year                        0
# Sub_Group_Name              0
# Victims_Above_50_Yrs      105
# Victims_Total               2
# Victims_Upto_10_15_Yrs    171
# Victims_Upto_10_Yrs       156
# Victims_Upto_15_18_Yrs    160
# Victims_Upto_18_30_Yrs     53
# Victims_Upto_30_50_Yrs     43
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Area_Name                 0
# Year                      0
# Sub_Group_Name            0
# Victims_Above_50_Yrs      0
# Victims_Total             0
# Victims_Upto_10_15_Yrs    0
# Victims_Upto_10_Yrs       0
# Victims_Upto_15_18_Yrs    0
# Victims_Upto_18_30_Yrs    0
# Victims_Upto_30_50_Yrs    0
# dtype: int64

# %%
df.head()
# Out:
#            Area_Name  Year   Sub_Group_Name  Victims_Above_50_Yrs  \
# 0     Andhra Pradesh  2001  1. Male Victims                  17.0
# 1  Arunachal Pradesh  2001  1. Male Victims                   1.0
# 2              Assam  2001  1. Male Victims                   2.0
# 3              Bihar  2001  1. Male Victims                  20.0
# 5       Chhattisgarh  2001  1. Male Victims                   8.0
#
#    Victims_Total  Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  \
# 0          144.0                     3.0                  1.0
# 1            6.0                     0.0                  0.0
# 2           38.0                     0.0                  0.0
# 3          232.0                     3.0                  0.0
# 5           73.0                     2.0                  2.0
#
#    Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs
# 0                     5.0                    54.0                    64.0
# ...

# %%
# Checking all the values which is present in the 'object' coulmns.

for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
# Out:
# Area_Name
# ['Andhra Pradesh' 'Arunachal Pradesh' 'Assam' 'Bihar' 'Chhattisgarh'
#  'Gujarat' 'Haryana' 'Himachal Pradesh' 'Jammu & Kashmir' 'Jharkhand'
#  'Karnataka' 'Madhya Pradesh' 'Maharashtra' 'Meghalaya' 'Mizoram'
#  'Nagaland' 'Odisha' 'Punjab' 'Tamil Nadu' 'Uttar Pradesh' 'West Bengal'
#  'Chandigarh' 'Daman & Diu' 'Delhi' 'Andaman & Nicobar Islands' 'Kerala'
#  'Rajasthan' 'Uttarakhand' 'Manipur' 'Sikkim' 'Goa' 'Tripura'
#  'Dadra & Nagar Haveli']
# Sub_Group_Name
# ['1. Male Victims' '2. Female Victims' '3. Total']

# %%
# Removing the value because its very high and its creating a big outlier.

df = df[df['Victims_Total']<1622]

# %%
df.describe()
# Out:
#               Year  Victims_Above_50_Yrs  Victims_Total  \
# count   722.000000            722.000000     722.000000
# mean   2005.524931              8.182825     103.475069
# std       2.851880             21.236854     231.543048
# min    2001.000000              0.000000       0.000000
# 25%    2003.000000              0.000000       6.000000
# 50%    2005.500000              1.000000      27.500000
# 75%    2008.000000              6.000000     101.500000
# max    2010.000000            157.000000    1551.000000
#
#        Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  \
# count              722.000000           722.000000              722.000000
# mean                 2.072022             1.891967                4.236842
# std                  6.212405             4.686211               12.080205
# min                  0.000000             0.000000                0.000000
# 25%                  0.000000             0.000000                0.000000
# ...

# %% [markdown]
#  Data Analysis And Visualizations on the Dataset

# %%
# Line Chart: Trend of total victims over the years
plt.figure(figsize=(20,8))
for area in df['Area_Name'].unique():
    area_data = df[df['Area_Name'] == area]
    plt.plot(area_data['Year'], area_data['Victims_Total'], marker='o', label=area)

plt.title('Trend of Total Victims Over the Years')
plt.xlabel('Year')
plt.ylabel('Total Victims')
plt.legend(title='Area Name')
plt.grid(True)
plt.show()

# %%
# Bar Chart: Total number of victims across different areas
plt.figure(figsize=(14,7))
plt.bar(df['Area_Name'], df['Victims_Total'], color='skyblue')
plt.title('Total Number of Victims Across Different Areas')
plt.xlabel('Area Name')
plt.ylabel('Total Victims')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Pie Chart: Proportional distribution of victims by age group for Andhra Pradesh
andhra_data = df[df['Area_Name'] == 'Andhra Pradesh'].iloc[0]
age_groups = ['Victims_Above_50_Yrs', 'Victims_Upto_10_15_Yrs', 'Victims_Upto_10_Yrs', 'Victims_Upto_15_18_Yrs', 'Victims_Upto_18_30_Yrs', 'Victims_Upto_30_50_Yrs']
age_values = [andhra_data[group] for group in age_groups]

plt.figure(figsize=(8, 8))
plt.pie(age_values, labels=age_groups, autopct='%1.1f%%', startangle=140)
plt.title('Proportional Distribution of Victims by Age Group in Andhra Pradesh')
plt.show()

# %%
# Line Chart: Trend of total victims over the years (using the same year here for demonstration)
plt.figure(figsize=(20,9))
plt.plot(df['Area_Name'], df['Victims_Total'], marker='o', linestyle='-', color='b')
plt.title('Total Victims Over Areas')
plt.xlabel('Area Name')
plt.ylabel('Total Victims')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,8))

# Calculate correlation matrix
corr_matrix = df[age_groups].corr()

# Plotting heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Between Different Victim Categories')
plt.show()

# %%
plt.figure(figsize=(15,8))

# Plotting line chart for each age group
for age_group in age_groups:
    plt.plot(df['Year'], df[age_group], marker='o', linestyle='-', label=age_group)

plt.title('Trend of Victims by Age Group Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Victims')
plt.legend(title='Age Groups')
plt.grid(True)
plt.show()

# %%
# Filter data for a specific state, e.g., 'Uttar Pradesh'
state_data = df[df['Area_Name'] == 'Uttar Pradesh'][age_groups].sum()

# Plotting pie chart
plt.figure(figsize=(8,8))
plt.pie(state_data, labels=age_groups, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Set2'))
plt.title('Proportion of Victims by Age Group in Uttar Pradesh')
plt.show()

# %% [markdown]
# Conclusions:
#
# Uttar Pradesh shows a significantly higher number of total victims in 2010 compared to other states, with a noticeable concentration in the 18-30 years age group.
# Bihar has consistently high numbers of male victims across the age groups, particularly in the 18-50 years range, indicating a possible trend of higher risk for men in these age brackets.
# The younger age groups (up to 18 years) generally have lower victim counts across most states, suggesting either lower exposure to risks or better protection mechanisms in place for children.
